# %%
'''
Pick bottom water calcite saturation field 'carb_ohm_cal_ben' using user-defined bathymetry
Update cGENIE output file of sedgem fields_sedgem_2d.nc
DeepDA using Baymag PSM may require the target field of "carb_ohm_cal_ben".
cGENIE output carb_ben_ohm_cal in fields_biogem_2d.nc file 
    corresponds to benthic ohmega for the base config topo, not user-defined bathymetry, thus is not useful.

By Mingsong Li
Date: April 23, 2020

'''

import yaml
import numpy as np
import pandas
import os
from netCDF4 import Dataset
from shutil import copyfile

sedgem_nc = 'fields_sedgem_2d.nc'
nc_field = 'carb_ohm_cal_ben'
biogem_nc = 'fields_biogem_3d.nc'
nc_field_ref = 'carb_ohm_cal'
t=0
dum_imax = 36
dum_jmax = 36
dum_dmax = 16
config_dir = '/mnt/c/Users/mul450/Dropbox/git/deepDA/'
config_name = "DeepDA_config.yml"
#config_name = "petmproxy3slices_v0.0.10gt1.csvexp_petm78_og1_qc_obs_20200203_test2.yml"
f = open(config_dir+config_name, 'r')
yml_dict = yaml.load(f, Loader=yaml.FullLoader)
f.close()

# %%
# *********************************************************************** %
def get_gdep(kmax, ez0, maxdep):
    z1 = ez0*(pow((1.0 + 1/ez0),(1.0/kmax)) - 1.0)
    tv4 = ez0*(pow((z1/ez0+1),0.5)-1)
    tv2 = 0
    tv1 = 0
    zro = np.zeros((kmax,1))
    zw = np.zeros((kmax+1,1))
    dz = np.zeros((kmax,1))
    dza = np.zeros((kmax,1))
    zro[kmax-1] = -tv4
    zw[kmax-1] = tv2

    for k in np.arange(1,kmax):
        if ez0 > 0:
            tv3 = ez0*(pow((z1/ez0+1),k)-1)
            dz[kmax-k] = tv3 - tv2
            tv2 = tv3
            tv5 = ez0*(pow((z1/ez0+1),(k+0.5))-1)
            if k < kmax:
                dza[kmax-k-1] = tv5 - tv4
            tv4 = tv5
            tv1 = tv1 + dz[kmax-k]
        else:
            dz[k-1] = 1.0/kmax
            dza[k-1] = 1.0/kmax

    for k in np.arange(kmax,1,-1):
        if k > 1:
            zro[k-2] = zro[k-1] - dza[k-2]
        zw[k-1] = zw[k] - dz[k-1]
    a = zw * maxdep
    a[0] = -1*maxdep # ensure the deepest one is 5km
    return a

# *********************************************************************** %
def calc_find_k(dum_depth, dum_kmax):
    par_D_max = 5000.0          # max depth (m)
    par_ez0 = 0.1               # GOLDSTEIN ez0 parameter
# set depth array
    D = get_gdep(dum_kmax,par_ez0,par_D_max) * -1
    #print(D)
    # set max k as default value - surface ocean
    loc_n_k = dum_kmax
    for n_k in np.arange(dum_kmax,2,-1):
        if dum_depth > D[n_k-1]:
            loc_n_k = n_k - 1
    if dum_depth > D[0]:
        loc_n_k = 1
    dum_k = [loc_n_k]
    return dum_k

# %%
dir_prior = yml_dict['core']['prior_dir']
nens = yml_dict['core']['nens']
dir_prior_full = os.listdir(dir_prior)
print(dir_prior_full[0])
prior_len = len(dir_prior_full)

print('>>    Read user-defined bathymetry, find bottom water calcite saturation')

for i in range(prior_len):
    name_nc_3d = dir_prior+'/'+ dir_prior_full[i]+'/'+ 'biogem' + '/' + biogem_nc
    ohm_cal_i = Dataset(name_nc_3d).variables[nc_field_ref][t,:,:,:]

    name_sedgem_2d = dir_prior+'/'+dir_prior_full[i]+'/sedgem/'+ sedgem_nc
    waterdepth = Dataset(name_sedgem_2d).variables['grid_topo']

    x = np.full((dum_imax, dum_jmax),np.nan)
    # step 1: find user-defined bathy   # step 2: find depth id k for each grid # step 3: read carb_ohm_cal, save as x

    for dum_imax_i in range(dum_imax):
        for dum_jmax_i in range(dum_jmax):
            
            waterdepthi = -1 * waterdepth[dum_imax_i, dum_jmax_i]
            ki = calc_find_k(waterdepthi, dum_dmax)
            kii = 16-ki[0]
            
            ohm_cal_val = np.ma.getdata(ohm_cal_i[kii,dum_imax_i,dum_jmax_i])
            ohm_cal_sur = np.ma.getdata(ohm_cal_i[0,dum_imax_i,dum_jmax_i])
            while ohm_cal_val<=0 and ohm_cal_sur>0:                
                kii = kii - 1
                #print('{}'.format(kii))
                ohm_cal_val = np.ma.getdata(ohm_cal_i[kii,dum_imax_i,dum_jmax_i])
                #print(ohm_cal_val)
                
            x[dum_imax_i,dum_jmax_i] = ohm_cal_val
            #print('i {} j {} depth {} ki {} kii {} ohm {} ohm_sur {}'.format(dum_imax_i, dum_jmax_i, waterdepthi, 16-ki[0], kii, ohm_cal_val, ohm_cal_i[0,dum_imax_i,dum_jmax_i]))
    x = x.reshape(1,36,36)
    x = np.ma.MaskedArray(x, x == 0.0)
    #print(x)
    nf = Dataset(name_sedgem_2d, 'a', format='NETCDF4')
    carb_ohm_cal = nf.createVariable(nc_field, 'f4', ('time','lat', 'lon'))
    carb_ohm_cal[:,:,:] = x
    carb_ohm_cal.units = ''
    nf.close()  # close the new file
    print('√ √   {} / {} Append 2d file: {}'.format(i+1,nens,name_sedgem_2d))
print('>>  End writing netCDF')
# Out:
# ML.petm009.ID.1
# >>    Read user-defined bathymetry, find bottom water calcite saturation
# √ √   0 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.1/sedgem/fields_sedgem_2d.nc
# √ √   1 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.10/sedgem/fields_sedgem_2d.nc
# √ √   2 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.100/sedgem/fields_sedgem_2d.nc
# √ √   3 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.101/sedgem/fields_sedgem_2d.nc
# √ √   4 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.102/sedgem/fields_sedgem_2d.nc
# √ √   5 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.103/sedgem/fields_sedgem_2d.nc
# √ √   6 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.104/sedgem/fields_sedgem_2d.nc
# √ √   7 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.105/sedgem/fields_sedgem_2d.nc
# √ √   8 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.106/sedgem/fields_sedgem_2d.nc
# √ √   9 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.107/sedgem/fields_sedgem_2d.nc
# √ √   10 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.108/sedgem/fields_sedgem_2d.nc
# √ √   11 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.109/sedgem/fields_sedgem_2d.nc
# √ √   12 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.11/sedgem/fields_sedgem_2d.nc
# √ √   13 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.110/sedgem/fields_sedgem_2d.nc
# √ √   14 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.111/sedgem/fields_sedgem_2d.nc
# √ √   15 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.112/sedgem/fields_sedgem_2d.nc
# √ √   16 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.113/sedgem/fields_sedgem_2d.nc
# √ √   17 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.114/sedgem/fields_sedgem_2d.nc
# √ √   18 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.115/sedgem/fields_sedgem_2d.nc
# √ √   19 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.116/sedgem/fields_sedgem_2d.nc
# √ √   20 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.117/sedgem/fields_sedgem_2d.nc
# √ √   21 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.118/sedgem/fields_sedgem_2d.nc
# √ √   22 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.119/sedgem/fields_sedgem_2d.nc
# √ √   23 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.12/sedgem/fields_sedgem_2d.nc
# √ √   24 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.120/sedgem/fields_sedgem_2d.nc
# √ √   25 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.121/sedgem/fields_sedgem_2d.nc
# √ √   26 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.122/sedgem/fields_sedgem_2d.nc
# √ √   27 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.123/sedgem/fields_sedgem_2d.nc
# √ √   28 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.124/sedgem/fields_sedgem_2d.nc
# √ √   29 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.125/sedgem/fields_sedgem_2d.nc
# √ √   30 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.126/sedgem/fields_sedgem_2d.nc
# √ √   31 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.127/sedgem/fields_sedgem_2d.nc
# √ √   32 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.128/sedgem/fields_sedgem_2d.nc
# √ √   33 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.129/sedgem/fields_sedgem_2d.nc
# √ √   34 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.13/sedgem/fields_sedgem_2d.nc
# √ √   35 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.130/sedgem/fields_sedgem_2d.nc
# √ √   36 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.131/sedgem/fields_sedgem_2d.nc
# √ √   37 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.132/sedgem/fields_sedgem_2d.nc
# √ √   38 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.133/sedgem/fields_sedgem_2d.nc
# √ √   39 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.134/sedgem/fields_sedgem_2d.nc
# √ √   40 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.135/sedgem/fields_sedgem_2d.nc
# √ √   41 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.136/sedgem/fields_sedgem_2d.nc
# √ √   42 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.137/sedgem/fields_sedgem_2d.nc
# √ √   43 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.138/sedgem/fields_sedgem_2d.nc
# √ √   44 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.139/sedgem/fields_sedgem_2d.nc
# √ √   45 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.14/sedgem/fields_sedgem_2d.nc
# √ √   46 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.140/sedgem/fields_sedgem_2d.nc
# √ √   47 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.141/sedgem/fields_sedgem_2d.nc
# √ √   48 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.142/sedgem/fields_sedgem_2d.nc
# √ √   49 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.143/sedgem/fields_sedgem_2d.nc
# √ √   50 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.144/sedgem/fields_sedgem_2d.nc
# √ √   51 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.145/sedgem/fields_sedgem_2d.nc
# √ √   52 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.146/sedgem/fields_sedgem_2d.nc
# √ √   53 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.147/sedgem/fields_sedgem_2d.nc
# √ √   54 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.148/sedgem/fields_sedgem_2d.nc
# √ √   55 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.149/sedgem/fields_sedgem_2d.nc
# √ √   56 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.15/sedgem/fields_sedgem_2d.nc
# √ √   57 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.150/sedgem/fields_sedgem_2d.nc
# √ √   58 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.151/sedgem/fields_sedgem_2d.nc
# √ √   59 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.152/sedgem/fields_sedgem_2d.nc
# √ √   60 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.153/sedgem/fields_sedgem_2d.nc
# √ √   61 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.154/sedgem/fields_sedgem_2d.nc
# √ √   62 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.155/sedgem/fields_sedgem_2d.nc
# √ √   63 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.156/sedgem/fields_sedgem_2d.nc
# √ √   64 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.157/sedgem/fields_sedgem_2d.nc
# √ √   65 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.158/sedgem/fields_sedgem_2d.nc
# √ √   66 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.159/sedgem/fields_sedgem_2d.nc
# √ √   67 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.16/sedgem/fields_sedgem_2d.nc
# √ √   68 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.160/sedgem/fields_sedgem_2d.nc
# √ √   69 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.161/sedgem/fields_sedgem_2d.nc
# √ √   70 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.162/sedgem/fields_sedgem_2d.nc
# √ √   71 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.163/sedgem/fields_sedgem_2d.nc
# √ √   72 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.164/sedgem/fields_sedgem_2d.nc
# √ √   73 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.165/sedgem/fields_sedgem_2d.nc
# √ √   74 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.166/sedgem/fields_sedgem_2d.nc
# √ √   75 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.167/sedgem/fields_sedgem_2d.nc
# √ √   76 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.168/sedgem/fields_sedgem_2d.nc
# √ √   77 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.169/sedgem/fields_sedgem_2d.nc
# √ √   78 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.17/sedgem/fields_sedgem_2d.nc
# √ √   79 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.170/sedgem/fields_sedgem_2d.nc
# √ √   80 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.171/sedgem/fields_sedgem_2d.nc
# √ √   81 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.172/sedgem/fields_sedgem_2d.nc
# √ √   82 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.173/sedgem/fields_sedgem_2d.nc
# √ √   83 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.174/sedgem/fields_sedgem_2d.nc
# √ √   84 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.175/sedgem/fields_sedgem_2d.nc
# √ √   85 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.176/sedgem/fields_sedgem_2d.nc
# √ √   86 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.177/sedgem/fields_sedgem_2d.nc
# √ √   87 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.178/sedgem/fields_sedgem_2d.nc
# √ √   88 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.179/sedgem/fields_sedgem_2d.nc
# √ √   89 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.18/sedgem/fields_sedgem_2d.nc
# √ √   90 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.180/sedgem/fields_sedgem_2d.nc
# √ √   91 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.181/sedgem/fields_sedgem_2d.nc
# √ √   92 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.182/sedgem/fields_sedgem_2d.nc
# √ √   93 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.183/sedgem/fields_sedgem_2d.nc
# √ √   94 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.184/sedgem/fields_sedgem_2d.nc
# √ √   95 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.185/sedgem/fields_sedgem_2d.nc
# √ √   96 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.186/sedgem/fields_sedgem_2d.nc
# √ √   97 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.187/sedgem/fields_sedgem_2d.nc
# √ √   98 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.188/sedgem/fields_sedgem_2d.nc
# √ √   99 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.189/sedgem/fields_sedgem_2d.nc
# √ √   100 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.19/sedgem/fields_sedgem_2d.nc
# √ √   101 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.190/sedgem/fields_sedgem_2d.nc
# √ √   102 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.191/sedgem/fields_sedgem_2d.nc
# √ √   103 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.192/sedgem/fields_sedgem_2d.nc
# √ √   104 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.193/sedgem/fields_sedgem_2d.nc
# √ √   105 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.194/sedgem/fields_sedgem_2d.nc
# √ √   106 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.195/sedgem/fields_sedgem_2d.nc
# √ √   107 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.196/sedgem/fields_sedgem_2d.nc
# √ √   108 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.197/sedgem/fields_sedgem_2d.nc
# √ √   109 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.198/sedgem/fields_sedgem_2d.nc
# √ √   110 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.199/sedgem/fields_sedgem_2d.nc
# √ √   111 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.2/sedgem/fields_sedgem_2d.nc
# √ √   112 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.20/sedgem/fields_sedgem_2d.nc
# √ √   113 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.200/sedgem/fields_sedgem_2d.nc
# √ √   114 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.21/sedgem/fields_sedgem_2d.nc
# √ √   115 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.22/sedgem/fields_sedgem_2d.nc
# √ √   116 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.23/sedgem/fields_sedgem_2d.nc
# √ √   117 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.24/sedgem/fields_sedgem_2d.nc
# √ √   118 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.25/sedgem/fields_sedgem_2d.nc
# √ √   119 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.26/sedgem/fields_sedgem_2d.nc
# √ √   120 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.27/sedgem/fields_sedgem_2d.nc
# √ √   121 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.28/sedgem/fields_sedgem_2d.nc
# √ √   122 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.29/sedgem/fields_sedgem_2d.nc
# √ √   123 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.3/sedgem/fields_sedgem_2d.nc
# √ √   124 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.30/sedgem/fields_sedgem_2d.nc
# √ √   125 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.31/sedgem/fields_sedgem_2d.nc
# √ √   126 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.32/sedgem/fields_sedgem_2d.nc
# √ √   127 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.33/sedgem/fields_sedgem_2d.nc
# √ √   128 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.34/sedgem/fields_sedgem_2d.nc
# √ √   129 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.35/sedgem/fields_sedgem_2d.nc
# √ √   130 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.36/sedgem/fields_sedgem_2d.nc
# √ √   131 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.37/sedgem/fields_sedgem_2d.nc
# √ √   132 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.38/sedgem/fields_sedgem_2d.nc
# √ √   133 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.39/sedgem/fields_sedgem_2d.nc
# √ √   134 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.4/sedgem/fields_sedgem_2d.nc
# √ √   135 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.40/sedgem/fields_sedgem_2d.nc
# √ √   136 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.41/sedgem/fields_sedgem_2d.nc
# √ √   137 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.42/sedgem/fields_sedgem_2d.nc
# √ √   138 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.43/sedgem/fields_sedgem_2d.nc
# √ √   139 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.44/sedgem/fields_sedgem_2d.nc
# √ √   140 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.45/sedgem/fields_sedgem_2d.nc
# √ √   141 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.46/sedgem/fields_sedgem_2d.nc
# √ √   142 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.47/sedgem/fields_sedgem_2d.nc
# √ √   143 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.48/sedgem/fields_sedgem_2d.nc
# √ √   144 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.49/sedgem/fields_sedgem_2d.nc
# √ √   145 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.5/sedgem/fields_sedgem_2d.nc
# √ √   146 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.50/sedgem/fields_sedgem_2d.nc
# √ √   147 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.51/sedgem/fields_sedgem_2d.nc
# √ √   148 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.52/sedgem/fields_sedgem_2d.nc
# √ √   149 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.53/sedgem/fields_sedgem_2d.nc
# √ √   150 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.54/sedgem/fields_sedgem_2d.nc
# √ √   151 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.55/sedgem/fields_sedgem_2d.nc
# √ √   152 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.56/sedgem/fields_sedgem_2d.nc
# √ √   153 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.57/sedgem/fields_sedgem_2d.nc
# √ √   154 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.58/sedgem/fields_sedgem_2d.nc
# √ √   155 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.59/sedgem/fields_sedgem_2d.nc
# √ √   156 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.6/sedgem/fields_sedgem_2d.nc
# √ √   157 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.60/sedgem/fields_sedgem_2d.nc
# √ √   158 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.61/sedgem/fields_sedgem_2d.nc
# √ √   159 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.62/sedgem/fields_sedgem_2d.nc
# √ √   160 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.63/sedgem/fields_sedgem_2d.nc
# √ √   161 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.64/sedgem/fields_sedgem_2d.nc
# √ √   162 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.65/sedgem/fields_sedgem_2d.nc
# √ √   163 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.66/sedgem/fields_sedgem_2d.nc
# √ √   164 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.67/sedgem/fields_sedgem_2d.nc
# √ √   165 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.68/sedgem/fields_sedgem_2d.nc
# √ √   166 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.69/sedgem/fields_sedgem_2d.nc
# √ √   167 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.7/sedgem/fields_sedgem_2d.nc
# √ √   168 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.70/sedgem/fields_sedgem_2d.nc
# √ √   169 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.71/sedgem/fields_sedgem_2d.nc
# √ √   170 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.72/sedgem/fields_sedgem_2d.nc
# √ √   171 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.73/sedgem/fields_sedgem_2d.nc
# √ √   172 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.74/sedgem/fields_sedgem_2d.nc
# √ √   173 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.75/sedgem/fields_sedgem_2d.nc
# √ √   174 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.76/sedgem/fields_sedgem_2d.nc
# √ √   175 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.77/sedgem/fields_sedgem_2d.nc
# √ √   176 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.78/sedgem/fields_sedgem_2d.nc
# √ √   177 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.79/sedgem/fields_sedgem_2d.nc
# √ √   178 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.8/sedgem/fields_sedgem_2d.nc
# √ √   179 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.80/sedgem/fields_sedgem_2d.nc
# √ √   180 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.81/sedgem/fields_sedgem_2d.nc
# √ √   181 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.82/sedgem/fields_sedgem_2d.nc
# √ √   182 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.83/sedgem/fields_sedgem_2d.nc
# √ √   183 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.84/sedgem/fields_sedgem_2d.nc
# √ √   184 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.85/sedgem/fields_sedgem_2d.nc
# √ √   185 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.86/sedgem/fields_sedgem_2d.nc
# √ √   186 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.87/sedgem/fields_sedgem_2d.nc
# √ √   187 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.88/sedgem/fields_sedgem_2d.nc
# √ √   188 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.89/sedgem/fields_sedgem_2d.nc
# √ √   189 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.9/sedgem/fields_sedgem_2d.nc
# √ √   190 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.90/sedgem/fields_sedgem_2d.nc
# √ √   191 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.91/sedgem/fields_sedgem_2d.nc
# √ √   192 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.92/sedgem/fields_sedgem_2d.nc
# √ √   193 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.93/sedgem/fields_sedgem_2d.nc
# √ √   194 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.94/sedgem/fields_sedgem_2d.nc
# √ √   195 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.95/sedgem/fields_sedgem_2d.nc
# √ √   196 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.96/sedgem/fields_sedgem_2d.nc
# √ √   197 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.97/sedgem/fields_sedgem_2d.nc
# √ √   198 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.98/sedgem/fields_sedgem_2d.nc
# √ √   199 / 200 Append 2d file: /mnt/d/cGENIE/ML.petm/ML.petm009/ML.petm009.ID.99/sedgem/fields_sedgem_2d.nc
# >>  End writing netCDF

# %%
nf.close()  # close the new file
