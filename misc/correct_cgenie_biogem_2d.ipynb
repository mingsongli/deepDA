# %%
"""
Generate surface field for cGENIE biogem_2d.nc file

"""
import yaml
import numpy as np
import pandas
import os
from netCDF4 import Dataset
from shutil import copyfile

biogem_nc_2d = 'fields_biogem_2d.nc'
nc_field_2d = ['ocn_sur_temp','ocn_sur_sal','carb_sur_ohm_cal']

biogem_nc_3d = 'fields_biogem_3d.nc'
nc_field_3d = ['ocn_temp','ocn_sal','carb_ohm_cal']

#t = 0  # time = 1
k = 0  # surface layer

config_dir = '/mnt/c/Users/mul450/Dropbox/git/deepDA/'
config_name = "DeepDA_config.yml"
#config_name = "petmproxy3slices_v0.0.10gt1.csvexp_petm78_og1_qc_obs_20200203_test2.yml"
f = open(config_dir+config_name, 'r')
yml_dict = yaml.load(f, Loader=yaml.FullLoader)
f.close()

dir_prior = yml_dict['core']['prior_dir']
nens = yml_dict['core']['nens']
dir_prior_full = os.listdir(dir_prior)
print(dir_prior_full[0])
prior_len = len(dir_prior_full)
print(prior_len)
# to test the first one
#prior_len = 1
print('>>    Read 3d, save 2d')
# Out:
# p0055c.Lietal2020impfac3pal.x0p6.delf2x10
# 60
# >>    Read 3d, save 2d

# %%
for i in range(prior_len):
    name_nc_3d = dir_prior+'/'+ dir_prior_full[i]+'/'+ 'biogem' + '/' + biogem_nc_3d
    name_nc_2d = dir_prior+'/'+ dir_prior_full[i]+'/'+ 'biogem' + '/' + biogem_nc_2d
    
    nf = Dataset(name_nc_2d, 'a', format='NETCDF4')
    
    for j in range(len(nc_field_3d)):
        
        nc_field_ref = nc_field_3d[j]
        nc_field_2di  = nc_field_2d[j]
        
        nc_field_x = Dataset(name_nc_3d).variables[nc_field_ref][:,k,:,:] # t, k, i, j
        t = np.shape(nc_field_x)[0]
        #print(t)
        #print(nc_field_2di)
        #print(nc_field_x)
        
        if nc_field_ref in ['ocn_temp']:
            ocn_sur_temp = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            ocn_sur_temp[:,:,:] = np.copy(nc_field_x.reshape(t,36,36))
            
        if nc_field_ref in ['ocn_sal']:
            ocn_sur_sal = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            ocn_sur_sal[:,:,:] = np.copy(nc_field_x.reshape(t,36,36))
            
        if nc_field_ref in ['carb_ohm_cal']:
            carb_sur_ohm_cal = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            carb_sur_ohm_cal[:,:,:] = np.copy(nc_field_x.reshape(t,36,36))
            
    nf.close()  # close the new file
    print('>>    {} done'.format(name_nc_2d))
print('>>  End writing netCDF')
# Out:
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p6.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x0p8.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p0.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p2.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p4.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p6.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x1p8.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p0.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p2.delf2x8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm015/p0055c.Lietal2020impfac3pal.x2p4.delf2x8/biogem/fields_biogem_2d.nc done
# >>  End writing netCDF

# %%
nf.close()  # close the new file
