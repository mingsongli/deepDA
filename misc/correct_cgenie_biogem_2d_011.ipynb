# %%
"""
Generate surface cGENIE field for biogem_2d.nc file

"""
import yaml
import numpy as np
import pandas
import os
from netCDF4 import Dataset
from shutil import copyfile

biogem_nc_2d = 'fields_biogem_2d.nc'
nc_field_2d = ['ocn_sur_temp','ocn_sur_sal','carb_sur_ohm_cal']

biogem_nc_3d = 'fields_biogem_3d.nc'
nc_field_3d = ['ocn_temp','ocn_sal','carb_ohm_cal']

t = 0  # time = 1
k = 0  # surface layer

config_dir = '/mnt/c/Users/mul450/Dropbox/git/deepDA/'
config_name = "DeepDA_config.yml"
#config_name = "petmproxy3slices_v0.0.10gt1.csvexp_petm78_og1_qc_obs_20200203_test2.yml"
f = open(config_dir+config_name, 'r')
yml_dict = yaml.load(f, Loader=yaml.FullLoader)
f.close()

# %%
dir_prior = yml_dict['core']['prior_dir']
nens = yml_dict['core']['nens']
dir_prior_full = os.listdir(dir_prior)
print(dir_prior_full[0])
prior_len = len(dir_prior_full)

# to test the first one
#prior_len = 1
print('>>    Read 3d, save 2d')

for i in range(prior_len):
    name_nc_3d = dir_prior+'/'+ dir_prior_full[i]+'/'+ 'biogem' + '/' + biogem_nc_3d
    name_nc_2d = dir_prior+'/'+ dir_prior_full[i]+'/'+ 'biogem' + '/' + biogem_nc_2d
    
    nf = Dataset(name_nc_2d, 'a', format='NETCDF4')
    
    for j in range(len(nc_field_3d)):
        
        nc_field_ref = nc_field_3d[j]
        nc_field_2di  = nc_field_2d[j]
        
        nc_field_x = Dataset(name_nc_3d).variables[nc_field_ref][t,k,:,:]
        #print(nc_field_2di)
        #print(nc_field_x)
        
        if nc_field_ref in ['ocn_temp']:
            ocn_sur_temp = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            ocn_sur_temp[:,:,:] = np.copy(nc_field_x.reshape(1,36,36))
            
        if nc_field_ref in ['ocn_sal']:
            ocn_sur_sal = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            ocn_sur_sal[:,:,:] = np.copy(nc_field_x.reshape(1,36,36))
            
        if nc_field_ref in ['carb_ohm_cal']:
            carb_sur_ohm_cal = nf.createVariable(nc_field_2di, 'f4', ('time','lat', 'lon'))
            carb_sur_ohm_cal[:,:,:] = np.copy(nc_field_x.reshape(1,36,36))
            
    nf.close()  # close the new file
    print('>>    {} done'.format(name_nc_2d))
print('>>  End writing netCDF')
# Out:
# ML.petm011.ID.1
# >>    Read 3d, save 2d
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.1/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.10/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.100/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.11/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.12/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.13/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.14/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.15/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.16/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.17/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.18/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.19/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.2/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.20/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.21/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.22/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.23/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.24/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.25/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.26/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.27/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.28/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.29/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.3/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.30/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.31/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.32/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.33/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.34/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.35/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.36/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.37/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.38/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.39/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.4/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.40/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.41/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.42/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.43/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.44/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.45/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.46/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.47/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.48/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.49/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.5/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.50/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.51/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.52/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.53/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.54/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.55/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.56/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.57/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.58/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.59/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.6/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.60/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.61/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.62/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.63/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.64/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.65/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.66/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.67/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.68/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.69/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.7/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.70/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.71/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.72/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.73/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.74/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.75/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.76/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.77/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.78/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.79/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.8/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.80/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.81/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.82/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.83/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.84/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.85/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.86/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.87/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.88/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.89/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.9/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.90/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.91/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.92/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.93/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.94/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.95/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.96/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.97/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.98/biogem/fields_biogem_2d.nc done
# >>    /mnt/d/cGENIE/ML.petm/ML.petm011/ML.petm011.ID.99/biogem/fields_biogem_2d.nc done
# >>  End writing netCDF

# %%
nf.close()  # close the new file
